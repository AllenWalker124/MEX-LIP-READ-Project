# %% [markdown]
# **Datasets**
#
# - Dataset para modos de articulación: git clone https://github.com/JaredEspinosa19/Dataset_TT
# - Dataset con vocales y consonantes: git clone https://github.com/JaredEspinosa19/Dataset_original

# %%
# Importamos las librerías necesarias

import os                   # Para manejar operaciones del sistema de archivos
import cv2                  # OpenCV para procesamiento de imágenes
import numpy as np           # Numpy para manejo de arrays y operaciones numéricas
import random                # Para la generación de números aleatorios
import tensorflow as tf      # TensorFlow para construir y entrenar modelos de Deep Learning
import matplotlib.pyplot as plt  # Para visualización de datos y gráficos
from tensorflow.keras.models import Sequential, save_model  # Para la construcción y guardado de modelos
from tensorflow.keras.layers import (Conv3D, Conv2D, Flatten, Dense, MaxPooling3D, MaxPooling2D, TimeDistributed, LSTM, Dropout, BatchNormalization)  # Capas utilizadas en el modelo
from tensorflow.keras.utils import Sequence, plot_model  # Utilidades para modelos y generación de secuencias de datos
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint  # Callbacks para mejorar el entrenamiento
from tensorflow.keras.preprocessing.image import (img_to_array, load_img, smart_resize, ImageDataGenerator)  # Preprocesamiento de imágenes
from tensorflow.keras.optimizers import Adam     # Optimizador Adam para ajustar los pesos del modelo
from sklearn.model_selection import train_test_split  # Para dividir el dataset en entrenamiento y prueba
from sklearn.metrics import (confusion_matrix, classification_report, roc_auc_score)  # Métricas para evaluar el modelo
from sklearn.utils import shuffle as sk_shuffle
from collections import Counter
import seaborn as sns  # Librería para visualización avanzada de datos

# Comprobamos si hay GPUs disponibles para utilizar con TensorFlow
print("Num GPUs disponibles: ", len(tf.config.list_physical_devices('GPU')))
if tf.config.list_physical_devices('GPU'):
    print("TensorFlow utilizará GPU")  # Si hay GPU, se utiliza
else:
    print("TensorFlow utilizará CPU")  # Si no hay GPU, se utiliza CPU


# Variables globales
batch_size = 65     # Tamaño del batch
n_frames_per_sample = 18  # Número de frames por muestra, ya que cada video se ha dividido en 18 imágenes
frame_height = 128   # Altura de cada frame (en píxeles)
frame_width = 128    # Ancho de cada frame (en píxeles)
n_filters = 16       # Número de filtros para las capas convolucionales
epochs = 100          # Número de épocas para el entrenamiento del modelo
n_channels = 3       # Número de canales en las imágenes (3 para RGB)
learning_rate = 0.0001  # Tasa de aprendizaje para el optimizador Adam

# Alternativa comentada para la tasa de aprendizaje más baja:
# learning_rate = 0.0001

dataset_path = 'Modo Sinfones'                    # Ruta del dataset que se utilizará
trained_model_path = 'ModelosEntrenados\ModeloMini\HYBRIDMINI_Sinfones_100epochs_Bs65_LrM4.keras'      # Ruta para guardar o cargar el modelo entrenado
# Out:
# c:\Users\pablo\miniconda3\envs\TT\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.4 when it was built against 1.14.2, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# Num GPUs disponibles:  1
# TensorFlow utilizará GPU

# %% [markdown]
# # Generador y funciones

# %%
## GENERADOR ##
class CustomDataGenerator(Sequence):
    def __init__(self, root_dir, mode='train', batch_size=32, frames_per_sample=18, target_size=(128, 128), n_channels=3, shuffle=False):
        """
        Inicializa el generador para una modalidad específica (train, validation o test).

        Parámetros:
        - root_dir: Ruta de la carpeta raíz que contiene los datos organizados por clasificación.
        - mode: Modalidad del generador ('train', 'validation', 'test').
        - batch_size: Tamaño del lote.
        - frames_per_sample: Número de frames por muestra.
        - target_size: Dimensiones de las imágenes (ancho y alto).
        - n_channels: Número de canales de color (3 para RGB).
        - shuffle: Indica si los datos deben mezclarse o no.
        """
        self.root_dir = root_dir  # Se pasa directamente la ruta de la clasificación
        self.mode = mode
        self.batch_size = batch_size
        self.frames_per_sample = frames_per_sample
        self.target_size = target_size
        self.n_channels = n_channels
        self.shuffle = shuffle  # Establece si los datos deben mezclarse o no

        # Las clases ahora son las subcarpetas dentro del directorio raíz que representa la clasificación
        self.classes = sorted(os.listdir(self.root_dir))
        self.class_to_index = {cls: idx for idx, cls in enumerate(self.classes)}
        
        self.dataset_info = self.prepare_dataset()
        self.samples = self.dataset_info[mode]

        # Si shuffle es True, mezcla las muestras al inicializar el generador
        if self.shuffle:
            self.samples = sk_shuffle(self.samples)

    def __len__(self):
        """
        Define la cantidad de lotes por época.
        """
        return len(self.samples) // self.batch_size

    def prepare_dataset(self):
        """
        Prepara el dataset dividiendo las muestras en train, validation y test.
        Asegura que cada subcarpeta tiene exactamente 68 muestras (o más, ajustable según el dataset).

        Retorna:
        - Diccionario con las muestras divididas en 'train', 'validation' y 'test'.
        """
        random.seed(42)  # Fija la semilla para asegurar consistencia en la división de datos
        all_files = {letter: [] for letter in self.classes}

        # Recorre cada subcarpeta (clase: Alveolar, Bilabial, Dental, etc.)
        for letter_dir in self.classes:
            letter_path = os.path.join(self.root_dir, letter_dir)
            
            for syllable_dir in os.listdir(letter_path):  # Subcarpetas de cada clase, como L, N, etc.
                syllable_path = os.path.join(letter_path, syllable_dir)

                for subsyllable_dir in os.listdir(syllable_path):  # Subcarpetas como LA, LE, LI, etc.
                    subsyllable_path = os.path.join(syllable_path, subsyllable_dir)
                    sample_paths = [os.path.join(subsyllable_path, sample_dir) for sample_dir in os.listdir(subsyllable_path)]
                    random.shuffle(sample_paths)  # Mezcla las muestras de forma aleatoria

                    # Asegurarse de que haya suficientes carpetas para train, val, y test
                    if len(sample_paths) >= 68:  # Asegurando que hay al menos 68 muestras
                        # Divide las muestras en train, val, y test
                        train_samples = sample_paths[:50]
                        val_samples = sample_paths[50:59]
                        test_samples = sample_paths[59:68]

                        for sample_dir in train_samples:
                            frame_files = [os.path.join(sample_dir, f) for f in sorted(os.listdir(sample_dir)) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                            if len(frame_files) == self.frames_per_sample:
                                all_files[letter_dir].append(('train', frame_files))  # Marcar como 'train'

                        for sample_dir in val_samples:
                            frame_files = [os.path.join(sample_dir, f) for f in sorted(os.listdir(sample_dir)) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                            if len(frame_files) == self.frames_per_sample:
                                all_files[letter_dir].append(('validation', frame_files))  # Marcar como 'validation'

                        for sample_dir in test_samples:
                            frame_files = [os.path.join(sample_dir, f) for f in sorted(os.listdir(sample_dir)) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
                            if len(frame_files) == self.frames_per_sample:
                                all_files[letter_dir].append(('test', frame_files))  # Marcar como 'test'

        # Organiza las muestras
        train, val, test = [], [], []
        for letter, samples in all_files.items():
            for sample in samples:
                mode, frame_files = sample
                if mode == 'train':
                    train.append((letter, frame_files))
                elif mode == 'validation':
                    val.append((letter, frame_files))
                elif mode == 'test':
                    test.append((letter, frame_files))

        return {'train': train, 'validation': val, 'test': test}

    def __getitem__(self, index):
        """
        Genera lotes de datos.

        Parámetros:
        - index: Índice del lote a generar.

        Retorna:
        - X_batch: Lote de imágenes.
        - y_batch: Lote de etiquetas (one-hot encoding).
        """
        batch_samples = self.samples[index * self.batch_size:(index + 1) * self.batch_size]
        X_batch = np.zeros((self.batch_size, self.frames_per_sample, *self.target_size, self.n_channels))
        y_batch = np.zeros((self.batch_size, len(self.classes)))

        # Procesa cada muestra del lote
        for i, (class_label, frames) in enumerate(batch_samples):
            class_index = self.class_to_index[class_label]

            # Carga los frames de la muestra
            images = [img_to_array(load_img(frame, color_mode='rgb', target_size=self.target_size)) / 255.0 for frame in frames]
            frames_array = np.array(images)

            X_batch[i] = frames_array
            y_batch[i, class_index] = 1   # Etiqueta one-hot

        return X_batch, y_batch

    def on_epoch_end(self):
        """
        Si shuffle está activado, mezcla las muestras al final de cada época.
        """
        if self.shuffle:
            self.samples = sk_shuffle(self.samples)




## ---------------------------------------------------------------------------------------------------------------------------- ##
## ---------------------------------------------------------------------------------------------------------------------------- ##

## FUNCIONES EXTRA (OPCIONALES) ##
#Funciones para observar los datos dentro de los generadores.

# Función para imprimir las muestras de cada partición (train, validation, test):
def print_sample_directories(generator):
    # Imprime las muestras de entrenamiento (train)
    print("Muestras en TRAIN:")
    for letter, frames in generator.dataset_info['train']:
        print(f"Clase: {letter}, Directorio de muestra: {os.path.dirname(frames[0])}")
    
    # Imprime las muestras de validación (validation)
    print("\nMuestras en VALIDATION:")
    for letter, frames in generator.dataset_info['validation']:
        print(f"Clase: {letter}, Directorio de muestra: {os.path.dirname(frames[0])}")
    
    # Imprime las muestras de prueba (test)
    print("\nMuestras en TEST:")
    for letter, frames in generator.dataset_info['test']:
        print(f"Clase: {letter}, Directorio de muestra: {os.path.dirname(frames[0])}")



# Esta función cuenta cuántas muestras hay en cada una de las particiones del dataset
def count_samples_per_division(generator):
    # Cuenta las muestras en el conjunto de entrenamiento (train)
    train_samples = len(generator.dataset_info['train'])
    
    # Cuenta las muestras en el conjunto de validación (validation)
    validation_samples = len(generator.dataset_info['validation'])
    
    # Cuenta las muestras en el conjunto de prueba (test)
    test_samples = len(generator.dataset_info['test'])
    
    # Imprime el total de muestras en cada partición
    print("\n\n")
    print(f"Total de muestras en TRAIN: {train_samples}")
    print(f"Total de muestras en VALIDATION: {validation_samples}")
    print(f"Total de muestras en TEST: {test_samples}")



# Esta función toma un batch de secuencias generadas por el generador y las visualiza.
# Por defecto, visualiza 4 secuencias, pero se puede ajustar el número de secuencias a mostrar.
def visualize_generated_sequences(generator, num_sequences=4):
    # Obtiene el primer batch del generador
    X_batch, y_batch = generator.__getitem__(0)
    
    # Asegura que no se intenten visualizar más secuencias de las que hay en el batch
    num_sequences = min(num_sequences, X_batch.shape[0])

    # Visualiza las secuencias
    for i in range(num_sequences):
        plt.figure(figsize=(15, 3))  # Ajusta el tamaño de la figura
        for j in range(generator.frames_per_sample):  # Recorre los frames de cada secuencia
            plt.subplot(1, generator.frames_per_sample, j + 1)  # Crea subplots para cada frame
            if generator.n_channels == 1:
                # Si las imágenes están en escala de grises
                plt.imshow(X_batch[i, j, :, :, 0], cmap='gray')
            else:
                # Si las imágenes están en formato RGB
                plt.imshow(X_batch[i, j, :, :, :])
            plt.axis('off')  # Oculta los ejes
        plt.show()  # Muestra las imágenes



# Código para verificar las muestras entregadas por los generadores
def contar_muestras_generador(generator):
    contador = Counter()
    for i in range(len(generator)):
        _, y_batch = generator[i]
        etiquetas = np.argmax(y_batch, axis=1)  # Obtener los índices de las clases
        for etiqueta in etiquetas:
            contador[etiqueta] += 1
    return contador

def print_sample_count(test_generator, sample_count):
    # Mapear índices a nombres de clases
    indice_a_clase = {v: k for k, v in test_generator.class_to_index.items()}

    # Imprimir el conteo de muestras por clase
    for idx, count in sample_count.items():
        print(f"Clase: {indice_a_clase[idx]}, Muestras: {count}")




## ---------------------------------------------------------------------------------------------------------------------------- ##
## ---------------------------------------------------------------------------------------------------------------------------- ##

# FUNCIÓN PARA IMPRIMIR LAS GRÁFICAS DE PRECISIÓN Y PERDIDA
def print_accuracy_loss(history):
    # Sumarizar la historia de la precisión
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Precisión del modelo')
    plt.ylabel('Precisión')
    plt.xlabel('Época')
    plt.legend(['Entrenamiento', 'Validación'], loc='upper left')
    plt.show()

    # Sumarizar la historia de la pérdida
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Pérdida del modelo')
    plt.ylabel('Pérdida')
    plt.xlabel('Época')
    plt.legend(['Entrenamiento', 'Validación'], loc='upper left')
    plt.show()


# FUNCIÓN PARA IMPRIMIR LA MATRIZ DE CONFUSIÓN Y EL REPORTE DE CLASIFICACIÓN
def print_conf_matriz_classif_report(model, test_generator):
    # Matriz de confusión e Informe de clasificación
    y_true = []
    y_pred = []

    # Recorremos el conjunto de datos de test para obtener las etiquetas reales y las predicciones
    for i in range(len(test_generator)):
        X_test, y_test = test_generator.__getitem__(i)
        preds = model.predict(X_test)

        y_true.extend(np.argmax(y_test, axis=1))  # Etiquetas reales
        y_pred.extend(np.argmax(preds, axis=1))   # Predicciones

    # Matriz de confusión
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Graficar la matriz de confusión
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_to_index.keys(), yticklabels=test_generator.class_to_index.keys())
    plt.xlabel('Predicciones')
    plt.ylabel('Etiquetas verdaderas')
    plt.title('Matriz de Confusión')
    plt.show()

    # Informe de clasificación
    print(classification_report(y_true, y_pred, target_names=test_generator.class_to_index.keys()))

# %% [markdown]
# # Generadores (train, validation, test)

# %%
# Crear generadores para train, validation y test con la opción de shuffle
train_generator = CustomDataGenerator(dataset_path, mode='train', batch_size=batch_size, shuffle=True)
validation_generator = CustomDataGenerator(dataset_path, mode='validation', batch_size=batch_size, shuffle=False)
test_generator = CustomDataGenerator(dataset_path, mode='test', batch_size=batch_size, shuffle=False)

# %% [markdown]
# #### Funciones extra (opcionales)
#
# Funciones para observar los datos dentro de los generadores. No es necesario ejecutar esta parte.

# %%
# print_sample_directories(train_generator)
# count_samples_per_division(train_generator)
# visualize_generated_sequences(train_generator, num_sequences=5)


# conteo_muestras = contar_muestras_generador(test_generator)
# print_sample_count(test_generator, conteo_muestras)

# %% [markdown]
# # Modelo CNN 3D

# %%
# Optimizador con el learning rate especificado
optimizer = Adam(learning_rate=learning_rate)

# Definición del modelo
model = Sequential()

# Ajuste de las dimensiones de entrada
input_shape = (n_frames_per_sample, frame_height, frame_width, n_channels)  # Sin el batch_size

# Capas 3D Conv
model.add(Conv3D(n_filters, kernel_size=(3, 3, 3), input_shape=input_shape, activation='relu')) # L1
model.add(MaxPooling3D(pool_size=(1, 2, 2)))                                
model.add(Conv3D(n_filters, kernel_size=(3, 3, 3), activation='relu'))                          # L2
model.add(MaxPooling3D(pool_size=(1, 2, 2)))                                
model.add(Conv3D(n_filters, kernel_size=(3, 3, 3), activation='relu'))                          # L3
model.add(MaxPooling3D(pool_size=(1, 2, 2)))                                
model.add(Conv3D(n_filters, kernel_size=(3, 3, 3), activation='relu'))                          # L4
model.add(MaxPooling3D(pool_size=(1, 2, 2)))  
# Capas 2D Conv
model.add(Conv2D(n_filters, kernel_size=(3, 3), activation='relu'))                             # L5
model.add(Conv2D(n_filters, kernel_size=(3, 3), activation='relu'))                             # L6

# Capas Flatten
model.add(Flatten())

# Capas totalmente conectadas
model.add(Dense(500, activation='relu'))
model.add(Dense(500, activation='relu'))

# Número de clases (ajustar según el número de clases en tu dataset)
n_classes = len(train_generator.class_to_index)  # Ajusta este valor si es diferente
model.add(Dense(n_classes, activation='softmax'))  # Salida

# Compilación del modelo
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Resumen del modelo
model.summary()

# Dibujo del modelo
# plot_model(model, 'CNN 3D.png', show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 16, 126, 126, 16)  1312
#
#  max_pooling3d (MaxPooling3D  (None, 16, 63, 63, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 14, 61, 61, 16)    6928
#
#  max_pooling3d_1 (MaxPooling  (None, 14, 30, 30, 16)   0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 12, 28, 28, 16)    6928
#
#  max_pooling3d_2 (MaxPooling  (None, 12, 14, 14, 16)   0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 10, 12, 12, 16)    6928
#
#  max_pooling3d_3 (MaxPooling  (None, 10, 6, 6, 16)     0
#  3D)
#
#  conv2d (Conv2D)             (None, 10, 4, 4, 16)      2320
#
#  conv2d_1 (Conv2D)           (None, 10, 2, 2, 16)      2320
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 500)               320500
#
#  dense_1 (Dense)             (None, 500)               250500
#
#  dense_2 (Dense)             (None, 4)                 2004
#
# =================================================================
# Total params: 599,740
# Trainable params: 599,740
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamiento del modelo
history = model.fit(
    train_generator,  # Pasa el generador directamente para entrenamiento
    validation_data=validation_generator,  # Usa el generador para validación
    epochs=epochs,  # Número de épocas
    steps_per_epoch=len(train_generator),
    validation_steps=len(validation_generator)
)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 47s 800ms/step - loss: 1.3576 - accuracy: 0.2985 - val_loss: 1.3526 - val_accuracy: 0.3077
# Epoch 2/100
# 50/50 [==============================] - 40s 785ms/step - loss: 1.3530 - accuracy: 0.3028 - val_loss: 1.3510 - val_accuracy: 0.3043
# Epoch 3/100
# 50/50 [==============================] - 40s 787ms/step - loss: 1.3518 - accuracy: 0.3114 - val_loss: 1.3487 - val_accuracy: 0.3077
# Epoch 4/100
# 50/50 [==============================] - 40s 787ms/step - loss: 1.3465 - accuracy: 0.3172 - val_loss: 1.3355 - val_accuracy: 0.3316
# Epoch 5/100
# 50/50 [==============================] - 40s 785ms/step - loss: 1.3291 - accuracy: 0.3551 - val_loss: 1.3019 - val_accuracy: 0.4103
# Epoch 6/100
# 50/50 [==============================] - 40s 789ms/step - loss: 1.3003 - accuracy: 0.3775 - val_loss: 1.2682 - val_accuracy: 0.4325
# Epoch 7/100
# 50/50 [==============================] - 40s 788ms/step - loss: 1.2492 - accuracy: 0.4215 - val_loss: 1.2119 - val_accuracy: 0.4188
# Epoch 8/100
# 50/50 [==============================] - 40s 786ms/step - loss: 1.1942 - accuracy: 0.4720 - val_loss: 1.1538 - val_accuracy: 0.5128
# Epoch 9/100
# 50/50 [==============================] - 40s 789ms/step - loss: 1.1247 - accuracy: 0.5040 - val_loss: 1.0689 - val_accuracy: 0.5453
# Epoch 10/100
# 50/50 [==============================] - 40s 789ms/step - loss: 1.0404 - accuracy: 0.5585 - val_loss: 0.9964 - val_accuracy: 0.5761
# Epoch 11/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.9799 - accuracy: 0.5917 - val_loss: 0.9384 - val_accuracy: 0.6256
# Epoch 12/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.9437 - accuracy: 0.6111 - val_loss: 0.9491 - val_accuracy: 0.6120
# Epoch 13/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.8955 - accuracy: 0.6480 - val_loss: 0.9436 - val_accuracy: 0.6222
# Epoch 14/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.8431 - accuracy: 0.6625 - val_loss: 0.8978 - val_accuracy: 0.6581
# Epoch 15/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.7917 - accuracy: 0.6920 - val_loss: 0.8315 - val_accuracy: 0.6838
# Epoch 16/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.7761 - accuracy: 0.6991 - val_loss: 0.8497 - val_accuracy: 0.6701
# Epoch 17/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.7395 - accuracy: 0.7148 - val_loss: 0.7971 - val_accuracy: 0.7197
# Epoch 18/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.6838 - accuracy: 0.7455 - val_loss: 0.7802 - val_accuracy: 0.7111
# Epoch 19/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.6776 - accuracy: 0.7406 - val_loss: 0.7821 - val_accuracy: 0.7009
# Epoch 20/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.6334 - accuracy: 0.7665 - val_loss: 0.7248 - val_accuracy: 0.7368
# Epoch 21/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.6092 - accuracy: 0.7695 - val_loss: 0.7302 - val_accuracy: 0.7487
# Epoch 22/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.5747 - accuracy: 0.7846 - val_loss: 0.7241 - val_accuracy: 0.7573
# Epoch 23/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.5496 - accuracy: 0.7935 - val_loss: 0.6790 - val_accuracy: 0.7590
# Epoch 24/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.5325 - accuracy: 0.7991 - val_loss: 0.6732 - val_accuracy: 0.7658
# Epoch 25/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.5227 - accuracy: 0.8012 - val_loss: 0.7205 - val_accuracy: 0.7641
# Epoch 26/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.4933 - accuracy: 0.8148 - val_loss: 0.6563 - val_accuracy: 0.7726
# Epoch 27/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.4630 - accuracy: 0.8283 - val_loss: 0.7329 - val_accuracy: 0.7487
# Epoch 28/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.4532 - accuracy: 0.8317 - val_loss: 0.6404 - val_accuracy: 0.7778
# Epoch 29/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.4126 - accuracy: 0.8462 - val_loss: 0.6628 - val_accuracy: 0.7829
# Epoch 30/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.4294 - accuracy: 0.8372 - val_loss: 0.6453 - val_accuracy: 0.7778
# Epoch 31/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.3808 - accuracy: 0.8625 - val_loss: 0.6555 - val_accuracy: 0.7641
# Epoch 32/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.3840 - accuracy: 0.8560 - val_loss: 0.6562 - val_accuracy: 0.7880
# Epoch 33/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.3635 - accuracy: 0.8634 - val_loss: 0.6682 - val_accuracy: 0.7949
# Epoch 34/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.3489 - accuracy: 0.8702 - val_loss: 0.6210 - val_accuracy: 0.7915
# Epoch 35/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.3240 - accuracy: 0.8825 - val_loss: 0.6543 - val_accuracy: 0.7726
# Epoch 36/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.3078 - accuracy: 0.8855 - val_loss: 0.6312 - val_accuracy: 0.7966
# Epoch 37/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.2858 - accuracy: 0.9015 - val_loss: 0.6489 - val_accuracy: 0.7966
# Epoch 38/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.2987 - accuracy: 0.8846 - val_loss: 0.7208 - val_accuracy: 0.7726
# Epoch 39/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.2775 - accuracy: 0.9043 - val_loss: 0.6091 - val_accuracy: 0.8000
# Epoch 40/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.2582 - accuracy: 0.9120 - val_loss: 0.6303 - val_accuracy: 0.7932
# Epoch 41/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.2290 - accuracy: 0.9243 - val_loss: 0.6286 - val_accuracy: 0.8120
# Epoch 42/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.2361 - accuracy: 0.9188 - val_loss: 0.6871 - val_accuracy: 0.7829
# Epoch 43/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.2507 - accuracy: 0.9151 - val_loss: 0.6340 - val_accuracy: 0.7880
# Epoch 44/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.2257 - accuracy: 0.9206 - val_loss: 0.6535 - val_accuracy: 0.8017
# Epoch 45/100
# 50/50 [==============================] - 40s 792ms/step - loss: 0.2000 - accuracy: 0.9320 - val_loss: 0.6512 - val_accuracy: 0.8034
# Epoch 46/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.1798 - accuracy: 0.9431 - val_loss: 0.6709 - val_accuracy: 0.8103
# Epoch 47/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.1870 - accuracy: 0.9342 - val_loss: 0.7242 - val_accuracy: 0.7949
# Epoch 48/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.2136 - accuracy: 0.9237 - val_loss: 0.6634 - val_accuracy: 0.8188
# Epoch 49/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.1471 - accuracy: 0.9532 - val_loss: 0.6458 - val_accuracy: 0.8068
# Epoch 50/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.1807 - accuracy: 0.9369 - val_loss: 0.6564 - val_accuracy: 0.8120
# Epoch 51/100
# 50/50 [==============================] - 40s 792ms/step - loss: 0.1381 - accuracy: 0.9551 - val_loss: 0.6827 - val_accuracy: 0.8034
# Epoch 52/100
# 50/50 [==============================] - 40s 797ms/step - loss: 0.1476 - accuracy: 0.9511 - val_loss: 0.7715 - val_accuracy: 0.8120
# Epoch 53/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.1294 - accuracy: 0.9591 - val_loss: 0.6784 - val_accuracy: 0.8017
# Epoch 54/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.1155 - accuracy: 0.9631 - val_loss: 0.7115 - val_accuracy: 0.8188
# Epoch 55/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.1183 - accuracy: 0.9640 - val_loss: 0.8032 - val_accuracy: 0.8239
# Epoch 56/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.1079 - accuracy: 0.9665 - val_loss: 0.7358 - val_accuracy: 0.8274
# Epoch 57/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.1070 - accuracy: 0.9674 - val_loss: 0.7263 - val_accuracy: 0.8137
# Epoch 58/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.0974 - accuracy: 0.9708 - val_loss: 0.7304 - val_accuracy: 0.8137
# Epoch 59/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.1016 - accuracy: 0.9698 - val_loss: 0.7314 - val_accuracy: 0.8256
# Epoch 60/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.0963 - accuracy: 0.9680 - val_loss: 0.8388 - val_accuracy: 0.8017
# Epoch 61/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.1010 - accuracy: 0.9649 - val_loss: 0.8805 - val_accuracy: 0.8068
# Epoch 62/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.0839 - accuracy: 0.9757 - val_loss: 0.7365 - val_accuracy: 0.8188
# Epoch 63/100
# 50/50 [==============================] - 40s 792ms/step - loss: 0.0770 - accuracy: 0.9769 - val_loss: 0.8206 - val_accuracy: 0.8171
# Epoch 64/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.0623 - accuracy: 0.9831 - val_loss: 0.8584 - val_accuracy: 0.7897
# Epoch 65/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.1318 - accuracy: 0.9554 - val_loss: 1.1169 - val_accuracy: 0.7333
# Epoch 66/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.1508 - accuracy: 0.9437 - val_loss: 0.8575 - val_accuracy: 0.8120
# Epoch 67/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.0875 - accuracy: 0.9711 - val_loss: 0.7466 - val_accuracy: 0.8359
# Epoch 68/100
# 50/50 [==============================] - 40s 793ms/step - loss: 0.0553 - accuracy: 0.9852 - val_loss: 0.7959 - val_accuracy: 0.8325
# Epoch 69/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.0456 - accuracy: 0.9914 - val_loss: 0.8371 - val_accuracy: 0.8120
# Epoch 70/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.0524 - accuracy: 0.9865 - val_loss: 0.8941 - val_accuracy: 0.8239
# Epoch 71/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.0431 - accuracy: 0.9877 - val_loss: 0.8498 - val_accuracy: 0.8154
# Epoch 72/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0421 - accuracy: 0.9926 - val_loss: 0.8866 - val_accuracy: 0.8342
# Epoch 73/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0479 - accuracy: 0.9865 - val_loss: 1.1090 - val_accuracy: 0.8017
# Epoch 74/100
# 50/50 [==============================] - 40s 792ms/step - loss: 0.1132 - accuracy: 0.9615 - val_loss: 0.9452 - val_accuracy: 0.8137
# Epoch 75/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.0415 - accuracy: 0.9917 - val_loss: 0.8554 - val_accuracy: 0.8342
# Epoch 76/100
# 50/50 [==============================] - 40s 794ms/step - loss: 0.0310 - accuracy: 0.9957 - val_loss: 0.8405 - val_accuracy: 0.8325
# Epoch 77/100
# 50/50 [==============================] - 40s 800ms/step - loss: 0.0236 - accuracy: 0.9972 - val_loss: 0.8591 - val_accuracy: 0.8342
# Epoch 78/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0239 - accuracy: 0.9957 - val_loss: 0.8902 - val_accuracy: 0.8239
# Epoch 79/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.0201 - accuracy: 0.9991 - val_loss: 0.9309 - val_accuracy: 0.8342
# Epoch 80/100
# 50/50 [==============================] - 40s 785ms/step - loss: 0.0181 - accuracy: 0.9978 - val_loss: 0.9645 - val_accuracy: 0.8222
# Epoch 81/100
# 50/50 [==============================] - 40s 792ms/step - loss: 0.0168 - accuracy: 0.9978 - val_loss: 1.0217 - val_accuracy: 0.8308
# Epoch 82/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0272 - accuracy: 0.9938 - val_loss: 1.0155 - val_accuracy: 0.8222
# Epoch 83/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.0372 - accuracy: 0.9905 - val_loss: 1.0808 - val_accuracy: 0.8103
# Epoch 84/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.0416 - accuracy: 0.9895 - val_loss: 0.9993 - val_accuracy: 0.8068
# Epoch 85/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.0605 - accuracy: 0.9815 - val_loss: 0.9957 - val_accuracy: 0.8359
# Epoch 86/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.0284 - accuracy: 0.9951 - val_loss: 1.0261 - val_accuracy: 0.8171
# Epoch 87/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0244 - accuracy: 0.9948 - val_loss: 0.9622 - val_accuracy: 0.8325
# Epoch 88/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.0148 - accuracy: 0.9982 - val_loss: 0.9703 - val_accuracy: 0.8444
# Epoch 89/100
# 50/50 [==============================] - 40s 786ms/step - loss: 0.0099 - accuracy: 0.9988 - val_loss: 1.0500 - val_accuracy: 0.8171
# Epoch 90/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0203 - accuracy: 0.9951 - val_loss: 1.0047 - val_accuracy: 0.8308
# Epoch 91/100
# 50/50 [==============================] - 40s 794ms/step - loss: 0.0249 - accuracy: 0.9929 - val_loss: 1.0269 - val_accuracy: 0.8274
# Epoch 92/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0273 - accuracy: 0.9932 - val_loss: 0.9554 - val_accuracy: 0.8239
# Epoch 93/100
# 50/50 [==============================] - 40s 790ms/step - loss: 0.0658 - accuracy: 0.9785 - val_loss: 1.0936 - val_accuracy: 0.8154
# Epoch 94/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.0634 - accuracy: 0.9778 - val_loss: 0.9407 - val_accuracy: 0.8171
# Epoch 95/100
# 50/50 [==============================] - 40s 787ms/step - loss: 0.0541 - accuracy: 0.9843 - val_loss: 1.1669 - val_accuracy: 0.8103
# Epoch 96/100
# 50/50 [==============================] - 40s 791ms/step - loss: 0.0711 - accuracy: 0.9769 - val_loss: 0.9870 - val_accuracy: 0.8154
# Epoch 97/100
# 50/50 [==============================] - 40s 789ms/step - loss: 0.0755 - accuracy: 0.9751 - val_loss: 1.0326 - val_accuracy: 0.8034
# Epoch 98/100
# 50/50 [==============================] - 40s 788ms/step - loss: 0.0441 - accuracy: 0.9868 - val_loss: 1.1102 - val_accuracy: 0.8051
# Epoch 99/100
# 50/50 [==============================] - 40s 796ms/step - loss: 0.0193 - accuracy: 0.9966 - val_loss: 0.9568 - val_accuracy: 0.8325
# Epoch 100/100
# 50/50 [==============================] - 42s 815ms/step - loss: 0.0098 - accuracy: 0.9991 - val_loss: 1.0120 - val_accuracy: 0.8427

# %%
# Guarda el modelo entrenado
model.save(trained_model_path)

# %% [markdown]
# #### ***accuracy***, ***loss***, ***confusion_matrix*** y ***classification_report***

# %%
print_accuracy_loss(history=history)
print_conf_matriz_classif_report(model=model, test_generator=test_generator)
# Out:
# 3/3 [==============================] - 0s 41ms/step
# 3/3 [==============================] - 0s 59ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 59ms/step
# 3/3 [==============================] - 0s 64ms/step
# 3/3 [==============================] - 0s 57ms/step
# 3/3 [==============================] - 0s 59ms/step
#                             precision    recall  f1-score   support
#
#      Dentolingual-alveolar       0.81      0.71      0.76       135
#       Labio-linguoalveolar       0.89      0.91      0.90       180
# Labiodental-linguoalveolar       0.75      0.78      0.77        90
#       Linguovelar-alveolar       0.81      0.86      0.84       180
#
#                   accuracy                           0.83       585
#                  macro avg       0.82      0.81      0.81       585
#               weighted avg       0.83      0.83      0.83       585

# %% [markdown]
# #### Funciones para cargar un modelo previamente entrenado y obtener ***confusion_matrix*** y ***classification_report***

# %%
def printss(history):
    # Sumarizar la historia de la precisión
    print("accuracy\n")
    print(history.history['accuracy'])
    print("validation accuracy\n")
    print(history.history['val_accuracy'])
    print("loss\n")
    print(history.history['loss'])
    print("validation loss\n")
    print(history.history['val_loss'])
printss(history=history)
# Out:
# accuracy
#
# [0.29846152663230896, 0.3027692437171936, 0.3113846182823181, 0.317230761051178, 0.3550769090652466, 0.3775384724140167, 0.42153847217559814, 0.47200000286102295, 0.5040000081062317, 0.5584615468978882, 0.591692328453064, 0.6110769510269165, 0.6480000019073486, 0.662461519241333, 0.6919999718666077, 0.6990769505500793, 0.7147692441940308, 0.7455384731292725, 0.7406153678894043, 0.7664615511894226, 0.7695384621620178, 0.7846153974533081, 0.7935384511947632, 0.7990769147872925, 0.801230788230896, 0.8147692084312439, 0.8283076882362366, 0.8316922783851624, 0.8461538553237915, 0.8372307419776917, 0.8624615669250488, 0.8560000061988831, 0.8633846044540405, 0.8701538443565369, 0.8824615478515625, 0.8855384588241577, 0.9015384912490845, 0.8846153616905212, 0.9043076634407043, 0.9120000004768372, 0.9243077039718628, 0.9187692403793335, 0.9150769114494324, 0.9206153750419617, 0.9319999814033508, 0.9430769085884094, 0.9341538548469543, 0.9236922860145569, 0.9532307982444763, 0.936923086643219, 0.9550769329071045, 0.9510769248008728, 0.9590769410133362, 0.9630769491195679, 0.9639999866485596, 0.9664615392684937, 0.9673846364021301, 0.9707692265510559, 0.9698461294174194, 0.9679999947547913, 0.964923083782196, 0.9756923317909241, 0.9769230484962463, 0.9830769300460815, 0.9553846120834351, 0.9436923265457153, 0.9710769057273865, 0.9852307438850403, 0.9913846254348755, 0.9864615201950073, 0.9876922965049744, 0.9926154017448425, 0.9864615201950073, 0.9615384340286255, 0.991692304611206, 0.9956923127174377, 0.9972307682037354, 0.9956923127174377, 0.9990769028663635, 0.9978461265563965, 0.9978461265563965, 0.9938461780548096, 0.990461528301239, 0.9895384907722473, 0.9815384745597839, 0.9950768947601318, 0.9947692155838013, 0.9981538653373718, 0.998769223690033, 0.9950768947601318, 0.9929230809211731, 0.9932307600975037, 0.9784615635871887, 0.9778461456298828, 0.9843077063560486, 0.9769230484962463, 0.9750769138336182, 0.9867692589759827, 0.9966154098510742, 0.9990769028663635]
# validation accuracy
#
# [0.3076923191547394, 0.3042735159397125, 0.3076923191547394, 0.33162394165992737, 0.41025641560554504, 0.4324786365032196, 0.4188034236431122, 0.5128205418586731, 0.5452991724014282, 0.5760684013366699, 0.6256410479545593, 0.6119658350944519, 0.6222222447395325, 0.6581196784973145, 0.6837607026100159, 0.6700854897499084, 0.7196581363677979, 0.7111111283302307, 0.7008547186851501, 0.7367521524429321, 0.7487179636955261, 0.7572649717330933, 0.7589743733406067, 0.7658119797706604, 0.764102578163147, 0.7726495862007141, 0.7487179636955261, 0.7777777910232544, 0.7829059958457947, 0.7777777910232544, 0.764102578163147, 0.788034200668335, 0.7948718070983887, 0.7914530038833618, 0.7726495862007141, 0.7965812087059021, 0.7965812087059021, 0.7726495862007141, 0.800000011920929, 0.7931624054908752, 0.811965823173523, 0.7829059958457947, 0.788034200668335, 0.8017094135284424, 0.8034188151359558, 0.8102564215660095, 0.7948718070983887, 0.8188034296035767, 0.8068376183509827, 0.811965823173523, 0.8034188151359558, 0.811965823173523, 0.8017094135284424, 0.8188034296035767, 0.8239316344261169, 0.8273504376411438, 0.8136752247810364, 0.8136752247810364, 0.8256410360336304, 0.8017094135284424, 0.8068376183509827, 0.8188034296035767, 0.8170940279960632, 0.7897436022758484, 0.7333333492279053, 0.811965823173523, 0.8358974456787109, 0.8324786424636841, 0.811965823173523, 0.8239316344261169, 0.8153846263885498, 0.8341880440711975, 0.8017094135284424, 0.8136752247810364, 0.8341880440711975, 0.8324786424636841, 0.8341880440711975, 0.8239316344261169, 0.8341880440711975, 0.8222222328186035, 0.8307692408561707, 0.8222222328186035, 0.8102564215660095, 0.8068376183509827, 0.8358974456787109, 0.8170940279960632, 0.8324786424636841, 0.8444444537162781, 0.8170940279960632, 0.8307692408561707, 0.8273504376411438, 0.8239316344261169, 0.8153846263885498, 0.8170940279960632, 0.8102564215660095, 0.8153846263885498, 0.8034188151359558, 0.8051282167434692, 0.8324786424636841, 0.8427350521087646]
# loss
#
# [1.3576242923736572, 1.3529558181762695, 1.3517552614212036, 1.3465228080749512, 1.3290883302688599, 1.3003062009811401, 1.2492114305496216, 1.1942298412322998, 1.1246566772460938, 1.0404242277145386, 0.9799019694328308, 0.943720281124115, 0.8954529762268066, 0.8430535793304443, 0.791727602481842, 0.7760610580444336, 0.7395240664482117, 0.683806836605072, 0.6775981187820435, 0.6334206461906433, 0.6091721653938293, 0.5746629238128662, 0.5496191382408142, 0.5324676036834717, 0.5226590037345886, 0.4932822585105896, 0.46302035450935364, 0.45324018597602844, 0.41256508231163025, 0.4293752610683441, 0.38082605600357056, 0.3840041756629944, 0.3635421395301819, 0.34890246391296387, 0.32397356629371643, 0.30778566002845764, 0.2858087122440338, 0.2987198829650879, 0.27747344970703125, 0.25815486907958984, 0.22898748517036438, 0.23609134554862976, 0.25071102380752563, 0.22569313645362854, 0.20002567768096924, 0.17977848649024963, 0.18697072565555573, 0.2135741263628006, 0.14706625044345856, 0.18068286776542664, 0.13811606168746948, 0.14759421348571777, 0.12936118245124817, 0.1154794991016388, 0.11829060316085815, 0.10785756260156631, 0.10702010989189148, 0.09744547307491302, 0.10162991285324097, 0.09627698361873627, 0.10104377567768097, 0.08391696214675903, 0.07703088968992233, 0.06232341751456261, 0.1317703276872635, 0.1508205533027649, 0.08747933059930801, 0.05533016100525856, 0.04559874162077904, 0.05238679051399231, 0.043135177344083786, 0.04207926616072655, 0.047898367047309875, 0.11319607496261597, 0.04151932895183563, 0.031038161367177963, 0.02357335016131401, 0.02394113689661026, 0.020074190571904182, 0.018129222095012665, 0.016806909814476967, 0.027204668149352074, 0.037224337458610535, 0.0415533147752285, 0.0605427511036396, 0.02840973436832428, 0.02443632110953331, 0.01477816328406334, 0.009885595180094242, 0.020333420485258102, 0.024940399453043938, 0.027301520109176636, 0.06578110158443451, 0.0634116604924202, 0.05413634330034256, 0.0711192935705185, 0.0754588171839714, 0.04406974837183952, 0.01927267387509346, 0.009793304838240147]
# validation loss
#
# [1.3525712490081787, 1.350950002670288, 1.3486790657043457, 1.335456132888794, 1.3018648624420166, 1.268180251121521, 1.2119420766830444, 1.15383780002594, 1.068929672241211, 0.9964300990104675, 0.9383902549743652, 0.9490512013435364, 0.9436255097389221, 0.897835910320282, 0.8315001130104065, 0.8497145175933838, 0.7970578670501709, 0.7801510095596313, 0.7821245193481445, 0.7247889041900635, 0.7301774621009827, 0.7241030931472778, 0.6790366768836975, 0.6732485294342041, 0.7205398082733154, 0.6562526226043701, 0.7329190373420715, 0.6403584480285645, 0.6627521514892578, 0.6453152298927307, 0.6554675102233887, 0.6562305092811584, 0.6682054996490479, 0.6209671497344971, 0.6542586088180542, 0.6312494874000549, 0.648932695388794, 0.7207741737365723, 0.6090558767318726, 0.63027024269104, 0.6285563111305237, 0.6871107220649719, 0.634000301361084, 0.65349280834198, 0.6512169241905212, 0.6708772778511047, 0.7241742014884949, 0.6634235978126526, 0.6457658410072327, 0.6564363241195679, 0.6826874017715454, 0.7715478539466858, 0.6783931255340576, 0.7114776968955994, 0.8032153248786926, 0.7358357906341553, 0.7262957096099854, 0.7303686141967773, 0.731375515460968, 0.8388420939445496, 0.880486249923706, 0.7365199327468872, 0.8206039071083069, 0.8584109544754028, 1.1168849468231201, 0.8575324416160583, 0.7465589642524719, 0.7959206700325012, 0.8370863199234009, 0.8940657377243042, 0.8498300909996033, 0.8866155743598938, 1.1090307235717773, 0.9451798796653748, 0.8554309606552124, 0.8405000567436218, 0.8591055870056152, 0.8902282118797302, 0.9308843016624451, 0.9645278453826904, 1.0217076539993286, 1.015464186668396, 1.0808478593826294, 0.9992609024047852, 0.9956709146499634, 1.0261149406433105, 0.962222695350647, 0.9703278541564941, 1.0499769449234009, 1.0046582221984863, 1.0269265174865723, 0.95538330078125, 1.0935866832733154, 0.9406632781028748, 1.1668812036514282, 0.9869701862335205, 1.03264582157135, 1.110182285308838, 0.9568470120429993, 1.0119500160217285]

# %%
# Función para cargar un modelo previamente entrenado
def load_trained_model(model_path):
    model = tf.keras.models.load_model(model_path)
    return model

# Cargar el modelo previamente entrenado
model = load_trained_model(trained_model_path)

# %%
print_conf_matriz_classif_report(model=model, test_generator=test_generator)
# Out:
# 3/3 [==============================] - 0s 58ms/step
# 3/3 [==============================] - 0s 55ms/step
# 3/3 [==============================] - 0s 59ms/step
# 3/3 [==============================] - 0s 57ms/step
# 3/3 [==============================] - 0s 57ms/step
# 3/3 [==============================] - 0s 52ms/step
# 3/3 [==============================] - 0s 61ms/step
# 3/3 [==============================] - 0s 61ms/step
# 3/3 [==============================] - 0s 56ms/step
#                             precision    recall  f1-score   support
#
#      Dentolingual-alveolar       0.81      0.71      0.76       135
#       Labio-linguoalveolar       0.89      0.91      0.90       180
# Labiodental-linguoalveolar       0.75      0.78      0.77        90
#       Linguovelar-alveolar       0.81      0.86      0.84       180
#
#                   accuracy                           0.83       585
#                  macro avg       0.82      0.81      0.81       585
#               weighted avg       0.83      0.83      0.83       585

# %% [markdown]
# # Grad-CAM
